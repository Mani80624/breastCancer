# %%
import pandas as pd

# %% [markdown]
# # Descripción de las bases de datos

# %% [markdown]
# ## CBIS-DDSM

# %% [markdown]
# Esta es una base de datos actualizada y estandarizada de la base de datos DDSM.
#
# La base de datos contiene 2,620 estudios y 10,239 imagenes mamograficas, los metadatos de la base está dividida por el tipo de anormalidad: Masa o calcificación, de cada anormalidad se tienen algunas variables en común como lo son:
#
# * patient_id
# * breast density
# * left or right breast
# * image view (proyecciones)
#    - Proyección CC (Cráneo-Caudal)
#    - Proyección MLO (Medio-Lateral Oblícua)
# * abnormality id
# * abnormality type
# * assessment (BIRADS)
# * pathology
# * subtlety
#   - 1 Muy sutil
#   - 2 Sutil
#   - 3 Moderadamente evidente
#   - 4 Evidente
#   - 5 Muy evidente
# * iamge file path
# * cropped image file path
# * ROI mask file path
#
# En caso de ser **calcificación** se tienen las siguiente varaibles:
#
# * calc type (describe el patrón morfológico): PLEOMORPHIC, AMORPHOUS, ...
# * cal distribution (Describe cómo están organbizadas espacialmente las calcificaciones dentro del tejido mamario): CLUSTERED, SEGMENTAL, REGIONAL,...
#
# En caso de ser **masa** se tienen las siguientes variables:
#
# * mass shape (Describe la forma geométrica de una masa): IRREGULAR, OVAL,...
# * mass margins (Describe el contorno o borde de una masa detectada en la mamografía): CIRCUMSCRIBED, SPICULATED, ILL_DEFINED,...
#
# [Base de datos CBIS-DDSM] (https://www.cancerimagingarchive.net/collection/cbis-ddsm/)

# %% [markdown]
# ## King Abdulaziz University Mammogram

# %% [markdown]
# La base de datos esta compuesta por un estudio en Arabia Saudita, es la primer base de datos clasificada en BIRADS de este país, la base de datos esta limitada por datos de abril de 2019 a marzo de 2020, la base de datos contiene 1416 casos y todos los casos de imagenes incluyen:
#
# * tipos de proyecciones de ambasa mamas
#   - CC
#   - MLO
# * clasificación BIRADS
#
# [Base de datos king Abdulaziz University Mammogram] (https://www.kaggle.com/datasets/asmaasaad/king-abdulaziz-university-mammogram-dataset?resource=download)

# %% [markdown]
# ## INbreast

# %% [markdown]
# ES una base de datos de Portugal, del centro hospitalario de S. Joao (CHSJ) en Porto, cuenta con 115 casos en total y 410 imagenes, de los cuales 90 casos son de mujeres con ambas mamas afectadas y 25 casos son de pacientes con masectomía igualmente dos imagenes por caso.
#
# Los datos recaudados son:
#
# * Laterality (L or R)
# * View (MLO or CC)
# * Acquisition date
# * File Name
# * ACR
# * BI-RADS
# * Mass
# * Micros
# * Distortion
# * Asymmetry
# * Findings notes (in Portuguese)
# * Other Notes
# * Lesion Annotation Status
# * Pectoral Muscle Annotation
# * Other annotations
#
# [Base de datos INbreast] (https://www.kaggle.com/datasets/ramanathansp20/inbreast-dataset)

# %% [markdown]
# ## MIAS

# %% [markdown]
# Es una base de datos de Reino Unido el cual contiene 332 imagenes, la informaciónd de cada imagen esta dada por:
#
# * REFNUM (número de referencia)
# * BG (Caracter de tejido de fondo)
# * CLASS (clase de la anormalidad presente: calcificación, circ, spic,...)
# * SEVERITY (Severidad de la anormalidad: B, M)
# * X (Coordenada X del centro de la anormalidad)
# * Y (Coordenada Y del centro de la anormalidad)
# * RADIUS (radio aproximado (en pixeles) de un circulo que encierra a la anormalidad)
#
# [Base de datos MIAS] (https://www.kaggle.com/datasets/kmader/mias-mammography)

# %% [markdown]
# # Importación de las bases de datos

# %%
# Base de datos de CBIS-DDSM: 4 archivos
C_DDSM_calc_t = pd.read_csv('/home/manuel/Descargas/Estudio de DB para cancer de mama/CBIS-DDSM/calc_case_description_train_set.csv')
C_DDSM_calc_test = pd.read_csv('/home/manuel/Descargas/Estudio de DB para cancer de mama/CBIS-DDSM/calc_case_description_test_set.csv')
C_DDSM_mass_t = pd.read_csv('/home/manuel/Descargas/Estudio de DB para cancer de mama/CBIS-DDSM/mass_case_description_train_set.csv')
C_DDSM_mass_test = pd.read_csv('/home/manuel/Descargas/Estudio de DB para cancer de mama/CBIS-DDSM/mass_case_description_test_set.csv')
C_DDSM_calc_t.head()
# Out:
#   patient_id  breast density left or right breast image view  abnormality id  \
# 0    P_00005               3                RIGHT         CC               1
# 1    P_00005               3                RIGHT        MLO               1
# 2    P_00007               4                 LEFT         CC               1
# 3    P_00007               4                 LEFT        MLO               1
# 4    P_00008               1                 LEFT         CC               1
#
#   abnormality type    calc type calc distribution  assessment  \
# 0    calcification    AMORPHOUS         CLUSTERED           3
# 1    calcification    AMORPHOUS         CLUSTERED           3
# 2    calcification  PLEOMORPHIC            LINEAR           4
# 3    calcification  PLEOMORPHIC            LINEAR           4
# 4    calcification          NaN          REGIONAL           2
#
#                  pathology  subtlety  \
# 0                MALIGNANT         3
# 1                MALIGNANT         3
# 2                   BENIGN         4
# 3                   BENIGN         4
# 4  BENIGN_WITHOUT_CALLBACK         3
#
#                                      image file path  \
# 0  Calc-Training_P_00005_RIGHT_CC/1.3.6.1.4.1.959...
# 1  Calc-Training_P_00005_RIGHT_MLO/1.3.6.1.4.1.95...
# 2  Calc-Training_P_00007_LEFT_CC/1.3.6.1.4.1.9590...
# 3  Calc-Training_P_00007_LEFT_MLO/1.3.6.1.4.1.959...
# 4  Calc-Training_P_00008_LEFT_CC/1.3.6.1.4.1.9590...
#
#                              cropped image file path  \
# 0  Calc-Training_P_00005_RIGHT_CC_1/1.3.6.1.4.1.9...
# 1  Calc-Training_P_00005_RIGHT_MLO_1/1.3.6.1.4.1....
# 2  Calc-Training_P_00007_LEFT_CC_1/1.3.6.1.4.1.95...
# 3  Calc-Training_P_00007_LEFT_MLO_1/1.3.6.1.4.1.9...
# 4  Calc-Training_P_00008_LEFT_CC_1/1.3.6.1.4.1.95...
#
#                                   ROI mask file path
# 0  Calc-Training_P_00005_RIGHT_CC_1/1.3.6.1.4.1.9...
# 1  Calc-Training_P_00005_RIGHT_MLO_1/1.3.6.1.4.1....
# 2  Calc-Training_P_00007_LEFT_CC_1/1.3.6.1.4.1.95...
# 3  Calc-Training_P_00007_LEFT_MLO_1/1.3.6.1.4.1.9...
# 4  Calc-Training_P_00008_LEFT_CC_1/1.3.6.1.4.1.95...

# %%
C_DDSM_mass_t.head()
# Out:
#   patient_id  breast_density left or right breast image view  abnormality id  \
# 0    P_00001               3                 LEFT         CC               1
# 1    P_00001               3                 LEFT        MLO               1
# 2    P_00004               3                 LEFT         CC               1
# 3    P_00004               3                 LEFT        MLO               1
# 4    P_00004               3                RIGHT        MLO               1
#
#   abnormality type                          mass shape   mass margins  \
# 0             mass  IRREGULAR-ARCHITECTURAL_DISTORTION     SPICULATED
# 1             mass  IRREGULAR-ARCHITECTURAL_DISTORTION     SPICULATED
# 2             mass            ARCHITECTURAL_DISTORTION    ILL_DEFINED
# 3             mass            ARCHITECTURAL_DISTORTION    ILL_DEFINED
# 4             mass                                OVAL  CIRCUMSCRIBED
#
#    assessment  pathology  subtlety  \
# 0           4  MALIGNANT         4
# 1           4  MALIGNANT         4
# 2           4     BENIGN         3
# 3           4     BENIGN         3
# 4           4     BENIGN         5
#
#                                      image file path  \
# 0  Mass-Training_P_00001_LEFT_CC/1.3.6.1.4.1.9590...
# 1  Mass-Training_P_00001_LEFT_MLO/1.3.6.1.4.1.959...
# 2  Mass-Training_P_00004_LEFT_CC/1.3.6.1.4.1.9590...
# 3  Mass-Training_P_00004_LEFT_MLO/1.3.6.1.4.1.959...
# 4  Mass-Training_P_00004_RIGHT_MLO/1.3.6.1.4.1.95...
#
#                              cropped image file path  \
# 0  Mass-Training_P_00001_LEFT_CC_1/1.3.6.1.4.1.95...
# 1  Mass-Training_P_00001_LEFT_MLO_1/1.3.6.1.4.1.9...
# 2  Mass-Training_P_00004_LEFT_CC_1/1.3.6.1.4.1.95...
# 3  Mass-Training_P_00004_LEFT_MLO_1/1.3.6.1.4.1.9...
# 4  Mass-Training_P_00004_RIGHT_MLO_1/1.3.6.1.4.1....
#
#                                   ROI mask file path
# 0  Mass-Training_P_00001_LEFT_CC_1/1.3.6.1.4.1.95...
# 1  Mass-Training_P_00001_LEFT_MLO_1/1.3.6.1.4.1.9...
# 2  Mass-Training_P_00004_LEFT_CC_1/1.3.6.1.4.1.95...
# 3  Mass-Training_P_00004_LEFT_MLO_1/1.3.6.1.4.1.9...
# 4  Mass-Training_P_00004_RIGHT_MLO_1/1.3.6.1.4.1....

# %%
# Base de datos de Abdulaziz University Mammogram
abdulaziz = pd.read_csv('/home/manuel/Descargas/Estudio de DB para cancer de mama/King Adbulaziz University Mammogram/BC with ultrasound.csv', sep=';')
abdulaziz.head()
# Out:
#         date   patientID patient No  DVD NO Right Mammogram     \
# 0  25-abr-19   BC 007741      PTNT1       2            BIRAD 2
# 1  24-abr-19   BC 005401      PTNT1       3            BIRAD 2
# 2  24-abr-19  BC 0021806      PTNT3       3            BIRAD 2
# 3  23-abr-19  BC 0026041     PTNT2        4            BIRAD 2
# 4  23-abr-19  BC 0026062      PTNT3       4            BIRAD 2
#
#   Left Mammogram   Right Ultrasound Left Ultrasound
# 0         BIRAD 2               NaN             NaN
# 1         BIRAD 2               NaN             NaN
# 2         BIRAD 2               NaN             NaN
# 3         BIRAD 2               NaN             NaN
# 4         BIRAD 2               NaN             NaN

# %%
# Base de datos INbreast
inbreast = pd.read_csv('/home/manuel/Descargas/Estudio de DB para cancer de mama/Inbreast/INbreast_complete.csv', sep=';') # Utilizar el xlxs
inbreast.head()
# Out:
#   Patient ID Patient age Laterality View  Acquisition date  File Name ACR  \
# 0    removed     removed          R   CC            201001   22678622   4
# 1    removed     removed          L   CC            201001   22678646   4
# 2    removed     removed          R  MLO            201001   22678670   4
# 3    removed     removed          L  MLO            201001   22678694   4
# 4    removed     removed          R   CC            201001   22614074   2
#
#   Bi-Rads Mass  Micros Distortion Asymmetry Findings Notes (in Portuguese)  \
# 0       1   NaN    NaN        NaN       NaN                         normal
# 1       3     X    NaN        NaN       NaN                         nódulo
# 2       1   NaN    NaN        NaN       NaN                         normal
# 3       3     X    NaN        NaN       NaN                         nódulo
# 4       5     X      X        NaN       NaN            nódulo QSE + micros
#
#   Other Notes Lesion Annotation Status Pectoral Muscle Annotation  \
# 0         NaN   No annotation (Normal)                        NaN
# 1         NaN                      NaN                        NaN
# 2         NaN   No annotation (Normal)                        NaN
# 3         NaN                      NaN                        NaN
# 4         NaN                      NaN                        NaN
#
#   Other Annotations
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
# Base de datos MIAS
mias = pd.read_csv('/home/manuel/Descargas/Estudio de DB para cancer de mama/MIAS/MIAS_Format_correct.csv', sep=';')
mias.head()
# Out:
#    REFNUM BG CLASS SEVERITY      X      Y  RADIUS
# 0  mdb001  G  CIRC        B  535.0  425.0   197.0
# 1  mdb002  G  CIRC        B  522.0  280.0    69.0
# 2  mdb003  D  NORM      NaN    NaN    NaN     NaN
# 3  mdb004  D  NORM      NaN    NaN    NaN     NaN
# 4  mdb005  F  CIRC        B  477.0  133.0    30.0

# %% [markdown]
# ## Combinación de la base de datos de CBIS-DDSM

# %% [markdown]
# Antes de combinar los datos de los diferentes archivos es necesario que renombremos las columnas de 'breast_density' por 'breast density', para poder tener un mejor manejo de la información:

# %%
# Solo se renombraran las columnas de los archivo que contengan la anormalidad de masa
C_DDSM_mass_t_formated = C_DDSM_mass_t.rename(columns={'breast_density':'breast density'})
C_DDSM_mass_test_formated = C_DDSM_mass_test.rename(columns={'breast_density':'breast density'})

# %% [markdown]
# Una vez renombradas las columnas podemos hacer la concatenación de los datos:

# %%
CBIS_DDSM = pd.concat([C_DDSM_calc_t, C_DDSM_calc_test, C_DDSM_mass_t_formated, C_DDSM_mass_test_formated])

# %% [markdown]
# Toda la información de la base de datos de CBIS-DDSM se tiene en una tabla, independientemente del tipo de anormalidad.

# %% [markdown]
# # Homogenizar los términos médicos

# %% [markdown]
# Antes de hacer combinar las columnas de cada base de datos es importante agregar una columna con la información de las diferentes bases de datos, es decir, el nombre de la base de datos, por lo que la siguiente tarea es agregar a cada base de datos una columna que se llame `DBName`.

# %%
# Para la base de CBIS_DDSM
CBIS_DDSM['DBName']='CBIS-DDSM'

# %%
# Para la base de Abdulaziz
abdulaziz['DBName']='Abdulaziz'

# %%
# Para la base de INbreast
inbreast['DBName']='INbreast'

# %%
# Base de datos MIAS
mias['DBName']='MIAS'

# %% [markdown]
# ## Condiciones de combinación de tablas

# %% [markdown]
# Vamos a homogenizar los términos médicos para poder hacer la unión de las bases de datos, primero, vamos a verificar qué columnas almacenan la misma información, entre los términos médicos que deben de homogenizarse son:
#
# * patient ID: Todas las bases de datos deben de contener el paciente ID sin modificarlas para conservar la información asociada a las mamografías originales, la columna debe de llamarse `patient_id`
# * Breast Laterality: esta columna representa el lado de la mama que representa la mamografía la columna debe de llamarse `breast_laterality`
# * View: representa las proyecciones, debe de llamarse `image_view`
# * Assessment: representa la clasificación en BIRADS, debe de llamarse `assessment`
# * pathology: representa si la anormalidad es benigna o maligna, debe de llamarse `pathology`
#
# Dadas estas condiciones debe de cambiarse los nombres de las columnas para que exista una buena relación entre las tablas.

# %% [markdown]
# Antes de realizar el cambio de nombre notemos que existen tablas que no estan completamente atomizados, es decir, que contienen más de un datos dentro de las celdas lo que puede causar confución o ambigüedad por parete de los usuarios, para nuestro caso, la tabla que no cumple con una estructura del todo correcta es la `Abdulaziz data set` por lo que se cambiará para este caso es la información que se acumula en `right mammogram` y `left mammogram`

# %% [markdown]
# ### Cambiar la estructura de la base de datos de abdulaziz

# %% [markdown]
# Para realizar el cambio de la estructura notemos que la tabla actual está estructurada como:
#
# |date|patientID|patient No| DVD NO| Right Mammogram| Left Mammogram| Right Ultrasound | Left Ultrasound| DBName|
#
#
# Agregaremos nuevas columnas para que la información pueda ser compatible con las estructuras de las demas tablas como sigue:
#
# |date|patientID|patient No| DVD NO| Laterality| assessment| DBName|
#
# Entonces de la siguiente manera haremos eso:

# %%
# La mofidicación de la tabla se relalizó en un script de Python llamado modifiedDF.py
abdulaziz_modificate = pd.read_csv('/home/manuel/Descargas/Estudio de DB para cancer de mama/King Adbulaziz University Mammogram/BC_abdulaziz_correct.csv', sep = ';')
abdulaziz_modificate['DBName'] = 'abdulaziz'
abdulaziz_modificate.head()
# Out:
#         date  patientID patient DVD NO laterality  assessment     DBName
# 0  25-abr-19   BC007741   PTNT1      2          R           2  abdulaziz
# 1  25-abr-19   BC007741   PTNT1      2          L           2  abdulaziz
# 2  24-abr-19   BC005401   PTNT1      3          R           2  abdulaziz
# 3  24-abr-19   BC005401   PTNT1      3          L           2  abdulaziz
# 4  24-abr-19  BC0021806   PTNT3      3          R           2  abdulaziz

# %% [markdown]
# Cambiemos los nombres de las columnas necesarias de las diferentes bases de datos para homogenizar los téminos médicos de acuerdo a lo establecido en las condiciones:

# %%
# Base de datos CBIS-DDSM, cambiamos la columa de left or right breast por breast_laterality

CBIS_DDSM = CBIS_DDSM.rename(columns={'left or right breast':'breast_laterality'})
CBIS_DDSM
# Out:
#     patient_id  breast density breast_laterality image view  abnormality id  \
# 0      P_00005               3             RIGHT         CC               1
# 1      P_00005               3             RIGHT        MLO               1
# 2      P_00007               4              LEFT         CC               1
# 3      P_00007               4              LEFT        MLO               1
# 4      P_00008               1              LEFT         CC               1
# ..         ...             ...               ...        ...             ...
# 373    P_01825               2             RIGHT        MLO               1
# 374    P_01833               2             RIGHT        MLO               1
# 375    P_01865               2              LEFT        MLO               1
# 376    P_01912               3             RIGHT         CC               1
# 377    P_01912               3             RIGHT        MLO               1
#
#     abnormality type    calc type calc distribution  assessment  \
# 0      calcification    AMORPHOUS         CLUSTERED           3
# 1      calcification    AMORPHOUS         CLUSTERED           3
# 2      calcification  PLEOMORPHIC            LINEAR           4
# 3      calcification  PLEOMORPHIC            LINEAR           4
# 4      calcification          NaN          REGIONAL           2
# ..               ...          ...               ...         ...
# 373             mass          NaN               NaN           3
# 374             mass          NaN               NaN           5
# 375             mass          NaN               NaN           4
# 376             mass          NaN               NaN           5
# 377             mass          NaN               NaN           5
#
#                    pathology  subtlety  \
# 0                  MALIGNANT         3
# 1                  MALIGNANT         3
# 2                     BENIGN         4
# 3                     BENIGN         4
# 4    BENIGN_WITHOUT_CALLBACK         3
# ..                       ...       ...
# 373  BENIGN_WITHOUT_CALLBACK         3
# 374                MALIGNANT         5
# 375                MALIGNANT         2
# 376                MALIGNANT         4
# 377                MALIGNANT         4
#
#                                        image file path  \
# 0    Calc-Training_P_00005_RIGHT_CC/1.3.6.1.4.1.959...
# 1    Calc-Training_P_00005_RIGHT_MLO/1.3.6.1.4.1.95...
# 2    Calc-Training_P_00007_LEFT_CC/1.3.6.1.4.1.9590...
# 3    Calc-Training_P_00007_LEFT_MLO/1.3.6.1.4.1.959...
# 4    Calc-Training_P_00008_LEFT_CC/1.3.6.1.4.1.9590...
# ..                                                 ...
# 373  Mass-Test_P_01825_RIGHT_MLO/1.3.6.1.4.1.9590.1...
# 374  Mass-Test_P_01833_RIGHT_MLO/1.3.6.1.4.1.9590.1...
# 375  Mass-Test_P_01865_LEFT_MLO/1.3.6.1.4.1.9590.10...
# 376  Mass-Test_P_01912_RIGHT_CC/1.3.6.1.4.1.9590.10...
# 377  Mass-Test_P_01912_RIGHT_MLO/1.3.6.1.4.1.9590.1...
#
#                                cropped image file path  \
# 0    Calc-Training_P_00005_RIGHT_CC_1/1.3.6.1.4.1.9...
# 1    Calc-Training_P_00005_RIGHT_MLO_1/1.3.6.1.4.1....
# 2    Calc-Training_P_00007_LEFT_CC_1/1.3.6.1.4.1.95...
# 3    Calc-Training_P_00007_LEFT_MLO_1/1.3.6.1.4.1.9...
# 4    Calc-Training_P_00008_LEFT_CC_1/1.3.6.1.4.1.95...
# ..                                                 ...
# 373  Mass-Test_P_01825_RIGHT_MLO_1/1.3.6.1.4.1.9590...
# 374  Mass-Test_P_01833_RIGHT_MLO_1/1.3.6.1.4.1.9590...
# 375  Mass-Test_P_01865_LEFT_MLO_1/1.3.6.1.4.1.9590....
# 376  Mass-Test_P_01912_RIGHT_CC_1/1.3.6.1.4.1.9590....
# 377  Mass-Test_P_01912_RIGHT_MLO_1/1.3.6.1.4.1.9590...
#
#                                     ROI mask file path mass shape  \
# 0    Calc-Training_P_00005_RIGHT_CC_1/1.3.6.1.4.1.9...        NaN
# 1    Calc-Training_P_00005_RIGHT_MLO_1/1.3.6.1.4.1....        NaN
# 2    Calc-Training_P_00007_LEFT_CC_1/1.3.6.1.4.1.95...        NaN
# 3    Calc-Training_P_00007_LEFT_MLO_1/1.3.6.1.4.1.9...        NaN
# 4    Calc-Training_P_00008_LEFT_CC_1/1.3.6.1.4.1.95...        NaN
# ..                                                 ...        ...
# 373  Mass-Test_P_01825_RIGHT_MLO_1/1.3.6.1.4.1.9590...  LOBULATED
# 374  Mass-Test_P_01833_RIGHT_MLO_1/1.3.6.1.4.1.9590...  IRREGULAR
# 375  Mass-Test_P_01865_LEFT_MLO_1/1.3.6.1.4.1.9590....  IRREGULAR
# 376  Mass-Test_P_01912_RIGHT_CC_1/1.3.6.1.4.1.9590....  IRREGULAR
# 377  Mass-Test_P_01912_RIGHT_MLO_1/1.3.6.1.4.1.9590...  IRREGULAR
#
#        mass margins     DBName
# 0               NaN  CBIS-DDSM
# 1               NaN  CBIS-DDSM
# 2               NaN  CBIS-DDSM
# 3               NaN  CBIS-DDSM
# 4               NaN  CBIS-DDSM
# ..              ...        ...
# 373  MICROLOBULATED  CBIS-DDSM
# 374     ILL_DEFINED  CBIS-DDSM
# 375     ILL_DEFINED  CBIS-DDSM
# 376      SPICULATED  CBIS-DDSM
# 377      SPICULATED  CBIS-DDSM
#
# [3568 rows x 17 columns]

# %%
"""Para la base de datos de Abdulaziz se cambian los nombres de las columnas: 
patientID por patient_id, laterality por breast laterality"""
abdulaziz_modificate = abdulaziz_modificate.rename(columns={'patientID':'patient_id', 'laterality':'breast_laterality'})
abdulaziz_modificate.head()
# Out:
#         date patient_id patient DVD NO breast_laterality  assessment  \
# 0  25-abr-19   BC007741   PTNT1      2                 R           2
# 1  25-abr-19   BC007741   PTNT1      2                 L           2
# 2  24-abr-19   BC005401   PTNT1      3                 R           2
# 3  24-abr-19   BC005401   PTNT1      3                 L           2
# 4  24-abr-19  BC0021806   PTNT3      3                 R           2
#
#       DBName
# 0  abdulaziz
# 1  abdulaziz
# 2  abdulaziz
# 3  abdulaziz
# 4  abdulaziz

# %%
"""Para la base de datos INbreast:
Patient ID por patient_id
Laterality por breast_laterality
View por image_view
Bi-Rads por assessment
"""
inbreast = inbreast.rename(columns={'Patient ID':'patient_id', 'Laterality':'breast_laterality', 'View':'image_view', 'Bi-Rads':'assessment'})
# Out:
#     patient_id Patient age breast_laterality image_view  Acquisition date  \
# 0      removed     removed                 R         CC            201001
# 1      removed     removed                 L         CC            201001
# 2      removed     removed                 R        MLO            201001
# 3      removed     removed                 L        MLO            201001
# 4      removed     removed                 R         CC            201001
# ..         ...         ...               ...        ...               ...
# 405    removed     removed                 L        MLO            201001
# 406    removed     removed                 L        MLO            200802
# 407    removed     removed                 R        MLO            200802
# 408    removed     removed                 L         CC            200802
# 409    removed     removed                 R         CC            200802
#
#      File Name ACR assessment Mass  Micros Distortion Asymmetry  \
# 0     22678622   4          1   NaN    NaN        NaN       NaN
# 1     22678646   4          3     X    NaN        NaN       NaN
# 2     22678670   4          1   NaN    NaN        NaN       NaN
# 3     22678694   4          3     X    NaN        NaN       NaN
# 4     22614074   2          5     X      X        NaN       NaN
# ..         ...  ..        ...   ...    ...        ...       ...
# 405   22613848   2          1   NaN    NaN        NaN       NaN
# 406   24055725   4          2   NaN      X        NaN       NaN
# 407   24055752   4          2   NaN      X        NaN       NaN
# 408   24055779   4          2   NaN      X        NaN       NaN
# 409   24055806   4          2   NaN      X        NaN       NaN
#
#     Findings Notes (in Portuguese) Other Notes Lesion Annotation Status  \
# 0                           normal         NaN   No annotation (Normal)
# 1                           nódulo         NaN                      NaN
# 2                           normal         NaN   No annotation (Normal)
# 3                           nódulo         NaN                      NaN
# 4              nódulo QSE + micros         NaN                      NaN
# ..                             ...         ...                      ...
# 405                         normal         NaN   No annotation (Normal)
# 406                         micros         NaN                      NaN
# 407                         micros         NaN                      NaN
# 408                         micros         NaN                      NaN
# 409                         micros         NaN                      NaN
#
#     Pectoral Muscle Annotation Other Annotations    DBName
# 0                          NaN               NaN  INbreast
# 1                          NaN               NaN  INbreast
# 2                          NaN               NaN  INbreast
# 3                          NaN               NaN  INbreast
# 4                          NaN               NaN  INbreast
# ..                         ...               ...       ...
# 405                        NaN               NaN  INbreast
# 406                        NaN               NaN  INbreast
# 407                        NaN               NaN  INbreast
# 408                        NaN               NaN  INbreast
# 409                        NaN               NaN  INbreast
#
# [410 rows x 18 columns]

# %%
# en este caso cambiaremos REFNUM por 'patient_id' y SEVERITY por 'pathology'
mias = mias.rename(columns={'REFNUM':'patient_id', 'SEVERITY':'pathology'})
mias.head()
# Out:
#   patient_id BG CLASS pathology      X      Y  RADIUS DBName
# 0     mdb001  G  CIRC         B  535.0  425.0   197.0   MIAS
# 1     mdb002  G  CIRC         B  522.0  280.0    69.0   MIAS
# 2     mdb003  D  NORM       NaN    NaN    NaN     NaN   MIAS
# 3     mdb004  D  NORM       NaN    NaN    NaN     NaN   MIAS
# 4     mdb005  F  CIRC         B  477.0  133.0    30.0   MIAS

# %% [markdown]
# Notemos que todavía tendremos problemas cuando se haga el análisis o el marge debido a que los datos por ejemplo de laterality_breast acumula no estan homogenizados en la base de datos CBIS-DDSM estan representados por 'RIGHT' o 'LEFT' mientras que el la base de datos de Abdulaziz o la de INbreast los datos estan como 'R' o 'L', algo similar sucede con la patología, en este caso lo mejor sería manejarlos de manera homologada para evitar problemas en el análisis por lo que se hará lo siguiente:
#
# 1. Para resolver el primer caso sera necesario modificar la base de datos de CBIS-DDSM a 'R' o 'L'
# 2. Para resolver el segundo caso es necesario modificar igualmente CBIS-DDSM a 'B', 'M'

# %%
copy_CBIS_DDSM = CBIS_DDSM

copy_CBIS_DDSM.breast_laterality = copy_CBIS_DDSM.breast_laterality.replace({'RIGHT':'R', 'LEFT':'L'})
copy_CBIS_DDSM.pathology = copy_CBIS_DDSM.pathology.replace({'MALIGNANT':'M', 'BENIGN':'B'})

copy_CBIS_DDSM.head()
# Out:
#   patient_id  breast density breast_laterality image view  abnormality id  \
# 0    P_00005               3                 R         CC               1
# 1    P_00005               3                 R        MLO               1
# 2    P_00007               4                 L         CC               1
# 3    P_00007               4                 L        MLO               1
# 4    P_00008               1                 L         CC               1
#
#   abnormality type    calc type calc distribution  assessment  \
# 0    calcification    AMORPHOUS         CLUSTERED           3
# 1    calcification    AMORPHOUS         CLUSTERED           3
# 2    calcification  PLEOMORPHIC            LINEAR           4
# 3    calcification  PLEOMORPHIC            LINEAR           4
# 4    calcification          NaN          REGIONAL           2
#
#                  pathology  subtlety  \
# 0                        M         3
# 1                        M         3
# 2                        B         4
# 3                        B         4
# 4  BENIGN_WITHOUT_CALLBACK         3
#
#                                      image file path  \
# 0  Calc-Training_P_00005_RIGHT_CC/1.3.6.1.4.1.959...
# 1  Calc-Training_P_00005_RIGHT_MLO/1.3.6.1.4.1.95...
# 2  Calc-Training_P_00007_LEFT_CC/1.3.6.1.4.1.9590...
# 3  Calc-Training_P_00007_LEFT_MLO/1.3.6.1.4.1.959...
# 4  Calc-Training_P_00008_LEFT_CC/1.3.6.1.4.1.9590...
#
#                              cropped image file path  \
# 0  Calc-Training_P_00005_RIGHT_CC_1/1.3.6.1.4.1.9...
# 1  Calc-Training_P_00005_RIGHT_MLO_1/1.3.6.1.4.1....
# 2  Calc-Training_P_00007_LEFT_CC_1/1.3.6.1.4.1.95...
# 3  Calc-Training_P_00007_LEFT_MLO_1/1.3.6.1.4.1.9...
# 4  Calc-Training_P_00008_LEFT_CC_1/1.3.6.1.4.1.95...
#
#                                   ROI mask file path mass shape mass margins  \
# 0  Calc-Training_P_00005_RIGHT_CC_1/1.3.6.1.4.1.9...        NaN          NaN
# 1  Calc-Training_P_00005_RIGHT_MLO_1/1.3.6.1.4.1....        NaN          NaN
# 2  Calc-Training_P_00007_LEFT_CC_1/1.3.6.1.4.1.95...        NaN          NaN
# 3  Calc-Training_P_00007_LEFT_MLO_1/1.3.6.1.4.1.9...        NaN          NaN
# 4  Calc-Training_P_00008_LEFT_CC_1/1.3.6.1.4.1.95...        NaN          NaN
#
#       DBName
# 0  CBIS-DDSM
# 1  CBIS-DDSM
# 2  CBIS-DDSM
# 3  CBIS-DDSM
# 4  CBIS-DDSM

# %% [markdown]
# Ya estamos en condiciones de hacer la unión de las bases de datos.

# %%
df = pd.concat([copy_CBIS_DDSM,abdulaziz_modificate,inbreast,mias])
df
# Out:
#     patient_id  breast density breast_laterality image view  abnormality id  \
# 0      P_00005             3.0                 R         CC             1.0
# 1      P_00005             3.0                 R        MLO             1.0
# 2      P_00007             4.0                 L         CC             1.0
# 3      P_00007             4.0                 L        MLO             1.0
# 4      P_00008             1.0                 L         CC             1.0
# ..         ...             ...               ...        ...             ...
# 325     mdb318             NaN               NaN        NaN             NaN
# 326     mdb319             NaN               NaN        NaN             NaN
# 327     mdb320             NaN               NaN        NaN             NaN
# 328     mdb321             NaN               NaN        NaN             NaN
# 329     mdb322             NaN               NaN        NaN             NaN
#
#     abnormality type    calc type calc distribution assessment  \
# 0      calcification    AMORPHOUS         CLUSTERED          3
# 1      calcification    AMORPHOUS         CLUSTERED          3
# 2      calcification  PLEOMORPHIC            LINEAR          4
# 3      calcification  PLEOMORPHIC            LINEAR          4
# 4      calcification          NaN          REGIONAL          2
# ..               ...          ...               ...        ...
# 325              NaN          NaN               NaN        NaN
# 326              NaN          NaN               NaN        NaN
# 327              NaN          NaN               NaN        NaN
# 328              NaN          NaN               NaN        NaN
# 329              NaN          NaN               NaN        NaN
#
#                    pathology  ...  Findings Notes (in Portuguese) Other Notes  \
# 0                          M  ...                             NaN         NaN
# 1                          M  ...                             NaN         NaN
# 2                          B  ...                             NaN         NaN
# 3                          B  ...                             NaN         NaN
# 4    BENIGN_WITHOUT_CALLBACK  ...                             NaN         NaN
# ..                       ...  ...                             ...         ...
# 325                      NaN  ...                             NaN         NaN
# 326                      NaN  ...                             NaN         NaN
# 327                      NaN  ...                             NaN         NaN
# 328                      NaN  ...                             NaN         NaN
# 329                      NaN  ...                             NaN         NaN
#
#     Lesion Annotation Status Pectoral Muscle Annotation Other Annotations  \
# 0                        NaN                        NaN               NaN
# 1                        NaN                        NaN               NaN
# 2                        NaN                        NaN               NaN
# 3                        NaN                        NaN               NaN
# 4                        NaN                        NaN               NaN
# ..                       ...                        ...               ...
# 325                      NaN                        NaN               NaN
# 326                      NaN                        NaN               NaN
# 327                      NaN                        NaN               NaN
# 328                      NaN                        NaN               NaN
# 329                      NaN                        NaN               NaN
#
#       BG CLASS   X   Y RADIUS
# 0    NaN   NaN NaN NaN    NaN
# 1    NaN   NaN NaN NaN    NaN
# 2    NaN   NaN NaN NaN    NaN
# 3    NaN   NaN NaN NaN    NaN
# 4    NaN   NaN NaN NaN    NaN
# ..   ...   ...  ..  ..    ...
# 325    D  NORM NaN NaN    NaN
# 326    D  NORM NaN NaN    NaN
# 327    D  NORM NaN NaN    NaN
# 328    D  NORM NaN NaN    NaN
# 329    D  NORM NaN NaN    NaN
#
# [7294 rows x 39 columns]

# %% [markdown]
# Convertir en un archivo csv:

# %%
df.to_csv('/home/manuel/Descargas/Estudio de DB para cancer de mama/DB_global.csv', index=False)

# %% [markdown]
# # Análisis de los datos

# %% [markdown]
# En esta sección se verá todo lo relacionado al análsis por lo que era de suma importancia los pasos anteriores.
#
# Verifiquemos cuantas columnas se tienen:

# %%
df.columns
# Out:
# Index(['patient_id', 'breast density', 'breast_laterality', 'image view',
#        'abnormality id', 'abnormality type', 'calc type', 'calc distribution',
#        'assessment', 'pathology', 'subtlety', 'image file path',
#        'cropped image file path', 'ROI mask file path', 'mass shape',
#        'mass margins', 'DBName', 'date', 'patient', 'DVD NO', 'Patient age',
#        'image_view', 'Acquisition date', 'File Name', 'ACR', 'Mass ', 'Micros',
#        'Distortion', 'Asymmetry', 'Findings Notes (in Portuguese)',
#        'Other Notes', 'Lesion Annotation Status', 'Pectoral Muscle Annotation',
#        'Other Annotations', 'BG', 'CLASS', 'X', 'Y', 'RADIUS'],
#       dtype='object')
